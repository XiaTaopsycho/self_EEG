# %%
# %matplotlib qt 
import mne
import os
from mne_bids import write_raw_bids,make_bids_basename

# %%
# Define the raw file name and get each subeject file name
raw_fname=('raw_fif/')
subjectlist=os.listdir(raw_fname)

# %%
for subject in subjectlist:
    montage=mne.channels.read_montage('standard_1020')#define the montage
    raw=mne.io.read_raw_fif(raw_fname + subject,montage)# read raw file by subject name
    events,events_id=mne.events_from_annotations(raw,event_id='auto')#get events and events_id from annotations
    bids_basename = make_bids_basename(subject[3:5], task='Moral')#make bids_base name, we can define "subject" "task""session" and so on
    write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)# now we can converted raw instance to BIDS
# Out:
# Opening raw data file raw_fif/sub10_raw.fif...
#     Range : 0 ... 1475374 =      0.000 ...  2950.748 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub10_raw.fif...
#     Range : 0 ... 1475374 =      0.000 ...  2950.748 secs
# Ready.
# Creating folder: ./BIDS/sub-10/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-10/sub-10_scans.tsv'...
#
# filename	acq_time
# eeg/sub-10_task-Moral_eeg.fif	2014-12-05T10:11:40
#
# Writing './BIDS/sub-10/eeg/sub-10_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 7.316	0.0	Response/R  2	3	3658
# 8.426	0.0	Stimulus/S  5	11	4213
# 9.798	0.0	Stimulus/S 15	16	4899
# 9.798	0.0	Response/R 13	8	4899
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1475374  =      0.000 ...  2950.748 secs...
# /home/xiatao/anaconda3/lib/python3.7/site-packages/mne_bids/write.py:407: UserWarning: No line frequency found, defaulting to 50 Hz
#   warn('No line frequency found, defaulting to 50 Hz')
# Writing './BIDS/sub-10/eeg/sub-10_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2950.748,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-10/eeg/sub-10_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-10/eeg/sub-10_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-10/eeg/sub-10_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-10/eeg/sub-10_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-10/eeg/sub-10_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub11_raw.fif...
#     Range : 0 ... 1434974 =      0.000 ...  2869.948 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub11_raw.fif...
#     Range : 0 ... 1434974 =      0.000 ...  2869.948 secs
# Ready.
# Creating folder: ./BIDS/sub-11/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-11/sub-11_scans.tsv'...
#
# filename	acq_time
# eeg/sub-11_task-Moral_eeg.fif	2014-12-05T14:31:43
#
# Writing './BIDS/sub-11/eeg/sub-11_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 8.032	0.0	Response/R  5	6	4016
# 9.142	0.0	Stimulus/S 11	14	4571
# 10.232	0.0	Stimulus/S 15	16	5116
# 10.232	0.0	Response/R 13	8	5116
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1434974  =      0.000 ...  2869.948 secs...
#
# Writing './BIDS/sub-11/eeg/sub-11_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2869.948,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-11/eeg/sub-11_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-11/eeg/sub-11_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-11/eeg/sub-11_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-11/eeg/sub-11_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-11/eeg/sub-11_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub13_raw.fif...
#     Range : 0 ... 1489374 =      0.000 ...  2978.748 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub13_raw.fif...
#     Range : 0 ... 1489374 =      0.000 ...  2978.748 secs
# Ready.
# Creating folder: ./BIDS/sub-13/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-13/sub-13_scans.tsv'...
#
# filename	acq_time
# eeg/sub-13_task-Moral_eeg.fif	2014-12-06T10:11:59
#
# Writing './BIDS/sub-13/eeg/sub-13_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 15.1	0.0	Response/R  5	6	7550
# 16.2	0.0	Stimulus/S 11	14	8100
# 17.548	0.0	Stimulus/S 15	16	8774
# 17.548	0.0	Response/R 13	8	8774
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1489374  =      0.000 ...  2978.748 secs...
#
# Writing './BIDS/sub-13/eeg/sub-13_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2978.748,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-13/eeg/sub-13_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-13/eeg/sub-13_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-13/eeg/sub-13_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-13/eeg/sub-13_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-13/eeg/sub-13_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub14_raw.fif...
#     Range : 0 ... 1546349 =      0.000 ...  3092.698 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub14_raw.fif...
#     Range : 0 ... 1546349 =      0.000 ...  3092.698 secs
# Ready.
# Creating folder: ./BIDS/sub-14/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-14/sub-14_scans.tsv'...
#
# filename	acq_time
# eeg/sub-14_task-Moral_eeg.fif	2014-12-06T14:37:46
#
# Writing './BIDS/sub-14/eeg/sub-14_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 23.628	0.0	Response/R  3	4	11814
# 24.728	0.0	Stimulus/S  7	12	12364
# 25.98	0.0	Response/R 14	9	12990
# 26.048	0.0	Response/R  1	2	13024
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1546349  =      0.000 ...  3092.698 secs...
#
# Writing './BIDS/sub-14/eeg/sub-14_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 3092.698,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-14/eeg/sub-14_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-14/eeg/sub-14_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-14/eeg/sub-14_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-14/eeg/sub-14_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-14/eeg/sub-14_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub15_raw.fif...
#     Range : 0 ... 1494199 =      0.000 ...  2988.398 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub15_raw.fif...
#     Range : 0 ... 1494199 =      0.000 ...  2988.398 secs
# Ready.
# Creating folder: ./BIDS/sub-15/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-15/sub-15_scans.tsv'...
#
# filename	acq_time
# eeg/sub-15_task-Moral_eeg.fif	2014-12-11T14:37:08
#
# Writing './BIDS/sub-15/eeg/sub-15_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 19.634	0.0	Response/R  5	6	9817
# 20.744	0.0	Stimulus/S 11	14	10372
# 22.046	0.0	Stimulus/S 15	16	11023
# 22.046	0.0	Response/R 13	8	11023
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1494199  =      0.000 ...  2988.398 secs...
#
# Writing './BIDS/sub-15/eeg/sub-15_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2988.398,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-15/eeg/sub-15_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-15/eeg/sub-15_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-15/eeg/sub-15_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-15/eeg/sub-15_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-15/eeg/sub-15_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub16_raw.fif...
#     Range : 0 ... 1453499 =      0.000 ...  2906.998 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub16_raw.fif...
#     Range : 0 ... 1453499 =      0.000 ...  2906.998 secs
# Ready.
# Creating folder: ./BIDS/sub-16/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-16/sub-16_scans.tsv'...
#
# filename	acq_time
# eeg/sub-16_task-Moral_eeg.fif	2014-12-12T05:17:18
#
# Writing './BIDS/sub-16/eeg/sub-16_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 16.994	0.0	Response/R  4	5	8497
# 18.094	0.0	Stimulus/S  9	13	9047
# 19.22	0.0	Stimulus/S 15	16	9610
# 19.22	0.0	Response/R 13	8	9610
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1453499  =      0.000 ...  2906.998 secs...
#
# Writing './BIDS/sub-16/eeg/sub-16_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2906.998,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-16/eeg/sub-16_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-16/eeg/sub-16_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-16/eeg/sub-16_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-16/eeg/sub-16_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-16/eeg/sub-16_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub17_raw.fif...
#     Range : 0 ... 1454499 =      0.000 ...  2908.998 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub17_raw.fif...
#     Range : 0 ... 1454499 =      0.000 ...  2908.998 secs
# Ready.
# Creating folder: ./BIDS/sub-17/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-17/sub-17_scans.tsv'...
#
# filename	acq_time
# eeg/sub-17_task-Moral_eeg.fif	2014-12-12T14:24:43
#
# Writing './BIDS/sub-17/eeg/sub-17_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 20.134	0.0	Response/R  5	6	10067
# 21.234	0.0	Stimulus/S 11	14	10617
# 22.388	0.0	Stimulus/S 15	16	11194
# 22.388	0.0	Response/R 13	8	11194
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1454499  =      0.000 ...  2908.998 secs...
#
# Writing './BIDS/sub-17/eeg/sub-17_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2908.998,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-17/eeg/sub-17_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-17/eeg/sub-17_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-17/eeg/sub-17_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-17/eeg/sub-17_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-17/eeg/sub-17_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub18_raw.fif...
#     Range : 0 ... 1417574 =      0.000 ...  2835.148 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub18_raw.fif...
#     Range : 0 ... 1417574 =      0.000 ...  2835.148 secs
# Ready.
# Creating folder: ./BIDS/sub-18/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-18/sub-18_scans.tsv'...
#
# filename	acq_time
# eeg/sub-18_task-Moral_eeg.fif	2014-12-13T05:09:20
#
# Writing './BIDS/sub-18/eeg/sub-18_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 8.936	0.0	Response/R  3	4	4468
# 10.036	0.0	Stimulus/S  7	12	5018
# 11.158	0.0	Response/R 14	9	5579
# 11.226	0.0	Response/R  4	5	5613
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1417574  =      0.000 ...  2835.148 secs...
#
# Writing './BIDS/sub-18/eeg/sub-18_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2835.148,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-18/eeg/sub-18_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-18/eeg/sub-18_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-18/eeg/sub-18_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-18/eeg/sub-18_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-18/eeg/sub-18_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub19_raw.fif...
#     Range : 0 ... 1416149 =      0.000 ...  2832.298 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub19_raw.fif...
#     Range : 0 ... 1416149 =      0.000 ...  2832.298 secs
# Ready.
# Creating folder: ./BIDS/sub-19/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-19/sub-19_scans.tsv'...
#
# filename	acq_time
# eeg/sub-19_task-Moral_eeg.fif	2014-12-13T09:59:36
#
# Writing './BIDS/sub-19/eeg/sub-19_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 6.21	0.0	Response/R  4	5	3105
# 7.31	0.0	Stimulus/S  9	13	3655
# 8.522	0.0	Stimulus/S 15	16	4261
# 8.522	0.0	Response/R 13	8	4261
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1416149  =      0.000 ...  2832.298 secs...
#
# Writing './BIDS/sub-19/eeg/sub-19_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2832.298,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-19/eeg/sub-19_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-19/eeg/sub-19_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-19/eeg/sub-19_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-19/eeg/sub-19_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-19/eeg/sub-19_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub20_raw.fif...
#     Range : 0 ... 1501849 =      0.000 ...  3003.698 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub20_raw.fif...
#     Range : 0 ... 1501849 =      0.000 ...  3003.698 secs
# Ready.
# Creating folder: ./BIDS/sub-20/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-20/sub-20_scans.tsv'...
#
# filename	acq_time
# eeg/sub-20_task-Moral_eeg.fif	2014-12-17T14:40:21
#
# Writing './BIDS/sub-20/eeg/sub-20_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 12.202	0.0	Response/R  1	2	6101
# 13.302	0.0	Stimulus/S  3	10	6651
# 14.708	0.0	Stimulus/S 15	16	7354
# 14.708	0.0	Response/R 13	8	7354
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1501849  =      0.000 ...  3003.698 secs...
#
# Writing './BIDS/sub-20/eeg/sub-20_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 3003.698,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-20/eeg/sub-20_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-20/eeg/sub-20_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-20/eeg/sub-20_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-20/eeg/sub-20_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-20/eeg/sub-20_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub21_raw.fif...
#     Range : 0 ... 1439874 =      0.000 ...  2879.748 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub21_raw.fif...
#     Range : 0 ... 1439874 =      0.000 ...  2879.748 secs
# Ready.
# Creating folder: ./BIDS/sub-21/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-21/sub-21_scans.tsv'...
#
# filename	acq_time
# eeg/sub-21_task-Moral_eeg.fif	2014-12-18T04:51:23
#
# Writing './BIDS/sub-21/eeg/sub-21_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 8.46	0.0	Response/R  1	2	4230
# 9.57	0.0	Stimulus/S  3	10	4785
# 10.866	0.0	Stimulus/S 15	16	5433
# 10.866	0.0	Response/R 13	8	5433
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1439874  =      0.000 ...  2879.748 secs...
#
# Writing './BIDS/sub-21/eeg/sub-21_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2879.748,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-21/eeg/sub-21_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-21/eeg/sub-21_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-21/eeg/sub-21_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-21/eeg/sub-21_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-21/eeg/sub-21_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub22_raw.fif...
#     Range : 0 ... 1423474 =      0.000 ...  2846.948 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub22_raw.fif...
#     Range : 0 ... 1423474 =      0.000 ...  2846.948 secs
# Ready.
# Creating folder: ./BIDS/sub-22/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-22/sub-22_scans.tsv'...
#
# filename	acq_time
# eeg/sub-22_task-Moral_eeg.fif	2014-12-18T09:55:23
#
# Writing './BIDS/sub-22/eeg/sub-22_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 11.42	0.0	Response/R  2	3	5710
# 12.53	0.0	Stimulus/S  5	11	6265
# 13.802	0.0	Stimulus/S 15	16	6901
# 13.802	0.0	Response/R 13	8	6901
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1423474  =      0.000 ...  2846.948 secs...
#
# Writing './BIDS/sub-22/eeg/sub-22_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2846.948,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-22/eeg/sub-22_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-22/eeg/sub-22_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-22/eeg/sub-22_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-22/eeg/sub-22_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-22/eeg/sub-22_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub23_raw.fif...
#     Range : 0 ... 1428149 =      0.000 ...  2856.298 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub23_raw.fif...
#     Range : 0 ... 1428149 =      0.000 ...  2856.298 secs
# Ready.
# Creating folder: ./BIDS/sub-23/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-23/sub-23_scans.tsv'...
#
# filename	acq_time
# eeg/sub-23_task-Moral_eeg.fif	2014-12-18T14:20:19
#
# Writing './BIDS/sub-23/eeg/sub-23_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 7.416	0.0	Response/R  2	3	3708
# 8.516	0.0	Stimulus/S  5	11	4258
# 9.624	0.0	Stimulus/S 15	16	4812
# 9.624	0.0	Response/R 13	8	4812
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1428149  =      0.000 ...  2856.298 secs...
#
# Writing './BIDS/sub-23/eeg/sub-23_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2856.298,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-23/eeg/sub-23_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-23/eeg/sub-23_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-23/eeg/sub-23_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-23/eeg/sub-23_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-23/eeg/sub-23_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub24_raw.fif...
#     Range : 0 ... 1509124 =      0.000 ...  3018.248 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub24_raw.fif...
#     Range : 0 ... 1509124 =      0.000 ...  3018.248 secs
# Ready.
# Creating folder: ./BIDS/sub-24/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-24/sub-24_scans.tsv'...
#
# filename	acq_time
# eeg/sub-24_task-Moral_eeg.fif	2014-12-19T05:31:15
#
# Writing './BIDS/sub-24/eeg/sub-24_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 17.978	0.0	Response/R  6	7	8989
# 19.088	0.0	Stimulus/S 13	15	9544
# 20.284	0.0	Stimulus/S 15	16	10142
# 20.284	0.0	Response/R 13	8	10142
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1509124  =      0.000 ...  3018.248 secs...
#
# Writing './BIDS/sub-24/eeg/sub-24_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 3018.248,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-24/eeg/sub-24_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-24/eeg/sub-24_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-24/eeg/sub-24_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-24/eeg/sub-24_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-24/eeg/sub-24_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub25_raw.fif...
#     Range : 0 ... 1422974 =      0.000 ...  2845.948 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub25_raw.fif...
#     Range : 0 ... 1422974 =      0.000 ...  2845.948 secs
# Ready.
# Creating folder: ./BIDS/sub-25/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-25/sub-25_scans.tsv'...
#
# filename	acq_time
# eeg/sub-25_task-Moral_eeg.fif	2014-12-19T10:15:46
#
# Writing './BIDS/sub-25/eeg/sub-25_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 7.774	0.0	Response/R  5	6	3887
# 8.884	0.0	Stimulus/S 11	14	4442
# 10.178	0.0	Stimulus/S 15	16	5089
# 10.178	0.0	Response/R 13	8	5089
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1422974  =      0.000 ...  2845.948 secs...
#
# Writing './BIDS/sub-25/eeg/sub-25_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2845.948,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-25/eeg/sub-25_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-25/eeg/sub-25_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-25/eeg/sub-25_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-25/eeg/sub-25_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-25/eeg/sub-25_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub26_raw.fif...
#     Range : 0 ... 1415224 =      0.000 ...  2830.448 secs
# Ready.
# ...
# Opening raw data file raw_fif/sub31_raw.fif...
#     Range : 0 ... 1488649 =      0.000 ...  2977.298 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub31_raw.fif...
#     Range : 0 ... 1488649 =      0.000 ...  2977.298 secs
# Ready.
# Creating folder: ./BIDS/sub-31/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
# sub-15	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-31/sub-31_scans.tsv'...
#
# filename	acq_time
# eeg/sub-31_task-Moral_eeg.fif	2014-12-26T09:59:11
#
# Writing './BIDS/sub-31/eeg/sub-31_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 7.924	0.0	Response/R  3	4	3962
# 9.024	0.0	Stimulus/S  7	12	4512
# 10.286	0.0	Stimulus/S 15	16	5143
# 10.286	0.0	Response/R 13	8	5143
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1488649  =      0.000 ...  2977.298 secs...
#
# Writing './BIDS/sub-31/eeg/sub-31_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2977.298,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-31/eeg/sub-31_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-31/eeg/sub-31_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-31/eeg/sub-31_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-31/eeg/sub-31_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-31/eeg/sub-31_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub06_raw.fif...
#     Range : 0 ... 1580849 =      0.000 ...  3161.698 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub06_raw.fif...
#     Range : 0 ... 1580849 =      0.000 ...  3161.698 secs
# Ready.
# Creating folder: ./BIDS/sub-06/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-06	n/a	n/a
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
# sub-14	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-06/sub-06_scans.tsv'...
#
# filename	acq_time
# eeg/sub-06_task-Moral_eeg.fif	2014-12-04T05:05:12
#
# Writing './BIDS/sub-06/eeg/sub-06_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 8.99	0.0	Response/R  2	3	4495
# 10.1	0.0	Stimulus/S  5	11	5050
# 11.516	0.0	Stimulus/S 15	16	5758
# 11.516	0.0	Response/R 13	8	5758
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1580849  =      0.000 ...  3161.698 secs...
#
# Writing './BIDS/sub-06/eeg/sub-06_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 3161.698,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-06/eeg/sub-06_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-06/eeg/sub-06_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-06/eeg/sub-06_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-06/eeg/sub-06_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-06/eeg/sub-06_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub07_raw.fif...
#     Range : 0 ... 1476624 =      0.000 ...  2953.248 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub07_raw.fif...
#     Range : 0 ... 1476624 =      0.000 ...  2953.248 secs
# Ready.
# Creating folder: ./BIDS/sub-07/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-06	n/a	n/a
# sub-07	n/a	n/a
# sub-10	n/a	n/a
# sub-11	n/a	n/a
# sub-13	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-07/sub-07_scans.tsv'...
#
# filename	acq_time
# eeg/sub-07_task-Moral_eeg.fif	2014-12-04T09:57:57
#
# Writing './BIDS/sub-07/eeg/sub-07_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 17.742	0.0	Response/R  4	5	8871
# 18.852	0.0	Stimulus/S  9	13	9426
# 20.012	0.0	Stimulus/S 15	16	10006
# 20.012	0.0	Response/R 13	8	10006
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1476624  =      0.000 ...  2953.248 secs...
#
# Writing './BIDS/sub-07/eeg/sub-07_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2953.248,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-07/eeg/sub-07_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-07/eeg/sub-07_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-07/eeg/sub-07_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-07/eeg/sub-07_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-07/eeg/sub-07_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub08_raw.fif...
#     Range : 0 ... 1477874 =      0.000 ...  2955.748 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub08_raw.fif...
#     Range : 0 ... 1477874 =      0.000 ...  2955.748 secs
# Ready.
# Creating folder: ./BIDS/sub-08/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-06	n/a	n/a
# sub-07	n/a	n/a
# sub-08	n/a	n/a
# sub-10	n/a	n/a
# sub-11	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-08/sub-08_scans.tsv'...
#
# filename	acq_time
# eeg/sub-08_task-Moral_eeg.fif	2014-12-04T14:09:16
#
# Writing './BIDS/sub-08/eeg/sub-08_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 4.986	0.0	Response/R  2	3	2493
# 6.096	0.0	Stimulus/S  5	11	3048
# 7.202	0.0	Stimulus/S 15	16	3601
# 7.202	0.0	Response/R 13	8	3601
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1477874  =      0.000 ...  2955.748 secs...
#
# Writing './BIDS/sub-08/eeg/sub-08_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2955.748,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-08/eeg/sub-08_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-08/eeg/sub-08_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-08/eeg/sub-08_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-08/eeg/sub-08_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-08/eeg/sub-08_task-Moral_eeg.fif [done]
# Opening raw data file raw_fif/sub09_raw.fif...
#     Range : 0 ... 1496424 =      0.000 ...  2992.848 secs
# Ready.
# Used Annotations descriptions: ['New Segment/', 'Response/R  1', 'Response/R  2', 'Response/R  3', 'Response/R  4', 'Response/R  5', 'Response/R  6', 'Response/R 13', 'Response/R 14', 'Stimulus/S  3', 'Stimulus/S  5', 'Stimulus/S  7', 'Stimulus/S  9', 'Stimulus/S 11', 'Stimulus/S 13', 'Stimulus/S 15']
# Opening raw data file raw_fif/sub09_raw.fif...
#     Range : 0 ... 1496424 =      0.000 ...  2992.848 secs
# Ready.
# Creating folder: ./BIDS/sub-09/eeg
#
# Writing './BIDS/participants.tsv'...
#
# participant_id	age	sex
# sub-06	n/a	n/a
# sub-07	n/a	n/a
# sub-08	n/a	n/a
# sub-09	n/a	n/a
# sub-10	n/a	n/a
#
# Writing './BIDS/participants.json'...
#
# {
#     "participant_id": {
#         "Description": "Unique participant identifier"
#     },
#     "age": {
#         "Description": "Age of the participant at time of testing",
#         "Units": "years"
#     },
#     "sex": {
#         "Description": "Biological sex of the participant",
#         "Levels": {
#             "F": "female",
#             "M": "male"
#         }
#     }
# }
#
# Writing './BIDS/sub-09/sub-09_scans.tsv'...
#
# filename	acq_time
# eeg/sub-09_task-Moral_eeg.fif	2014-12-05T05:05:53
#
# Writing './BIDS/sub-09/eeg/sub-09_task-Moral_events.tsv'...
#
# onset	duration	trial_type	value	sample
# 0.0	0.0	New Segment/	1	0
# 8.646	0.0	Response/R  1	2	4323
# 9.748	0.0	Stimulus/S  3	10	4874
# 10.968	0.0	Stimulus/S 15	16	5484
# 10.968	0.0	Response/R 13	8	5484
#
# Writing './BIDS/dataset_description.json'...
#
# {
#     "Name": " ",
#     "BIDSVersion": "1.2.0"
# }
# Reading 0 ... 1496424  =      0.000 ...  2992.848 secs...
#
# Writing './BIDS/sub-09/eeg/sub-09_task-Moral_eeg.json'...
#
# {
#     "TaskName": "Moral",
#     "Manufacturer": "Elekta",
#     "PowerLineFrequency": 50,
#     "SamplingFrequency": 500.0,
#     "SoftwareFilters": "n/a",
#     "RecordingDuration": 2992.848,
#     "RecordingType": "continuous",
#     "EEGReference": "n/a",
#     "EEGGround": "n/a",
#     "EEGPlacementScheme": "based on the extended 10/20 system",
#     "EEGChannelCount": 63,
#     "EOGChannelCount": 0,
#     "ECGChannelCount": 0,
#     "EMGChannelCount": 0,
#     "MiscChannelCount": 0,
#     "TriggerChannelCount": 0
# }
#
# Writing './BIDS/sub-09/eeg/sub-09_task-Moral_channels.tsv'...
#
# name	type	units	low_cutoff	high_cutoff	description	sampling_frequency	status
# FP1	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FZ	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F3	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# F7	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# FT9	EEG	V	0.0	250.0	ElectroEncephaloGram	500.0	good
# Copying data files to ./BIDS/sub-09/eeg/sub-09_task-Moral_eeg.fif
# Writing /home/xiatao/hcp_EEG/BIDS/sub-09/eeg/sub-09_task-Moral_eeg.fif
# <ipython-input-60-7484f7e36b88>:6: RuntimeWarning: This filename (./BIDS/sub-09/eeg/sub-09_task-Moral_eeg.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   write_raw_bids(raw, bids_basename=bids_basename, output_path='./BIDS',event_id=events_id,events_data=events,overwrite=True)
# Closing /home/xiatao/hcp_EEG/BIDS/sub-09/eeg/sub-09_task-Moral_eeg.fif [done]
